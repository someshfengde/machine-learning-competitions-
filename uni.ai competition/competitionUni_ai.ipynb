# %% [markdown]
# # importing required libraries

# %%
# !pip install fastbook
# Out:
# ...
#      |████████████████████████████████| 727kB 11.3MB/s
# ...
#      |████████████████████████████████| 194kB 26.0MB/s
# ...
#      |████████████████████████████████| 1.2MB 44.5MB/s
# ...
#      |████████████████████████████████| 51kB 5.5MB/s
# ...
#      |████████████████████████████████| 61kB 5.8MB/s
# ...
#      |████████████████████████████████| 61kB 5.7MB/s
# ...
#   Found existing installation: fastai 1.0.61
#     Uninstalling fastai-1.0.61:
#       Successfully uninstalled fastai-1.0.61
# ...

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import tensorflow as tf 
from fastbook import *

# %% [markdown]
# # exploring the data

# %%
train_df_target = pd.read_csv('/content/Training Data Target.csv')

# %%
train_df_target.value_counts('category')
# Out:
# category
# Phones                       7124
# Fashion                      2195
# Pet Supplies                  910
# Ereaders                      887
# Fitness                       874
# TVs                           426
# Laptops                       308
# Home Decor                    238
# Consumer Durables             186
# Toys                           58
# Back to School                 19
# Gaming                         10
# Groceries                       8
# Kitchen cleaning Supplies       2
# dtype: int64

# %%
train_df_target.value_counts('aov')
# Out:
# aov
# -9999    13245
# dtype: int64

# %%
train_df.head()
# Out:
#    user_id   aov category
# 0    13153 -9999   Phones
# 1    42853 -9999   Phones
# 2    30550 -9999   Phones
# 3     9797 -9999   Phones
# 4     8171 -9999   Phones

# %%
train_data = pd.read_csv('/content/Test Data.csv')

# %%
train_data.head()
# Out:
#    Unnamed: 0  user_id      aov category
# 0           0    43323  19115.0   Phones
# 1           1    43323  29309.0   Phones
# 2           2    43323  15293.0   Phones
# 3           3    43323  23548.0   Phones
# 4           4    43323    751.0  Fashion

# %%
train_data.value_counts('category')
# Out:
# category
# Phones                       44627
# Fashion                      40082
# Home Decor                   19911
# Toys                         14096
# Groceries                     8559
# Back to School                8405
# Gaming                        8109
# Consumer Durables             7984
# Books                         3968
# Ereaders                      2163
# Pet Supplies                  2059
# Beauty Products               2055
# Kitchen cleaning Supplies     2042
# Painiting Supplies            1987
# Board Games                   1981
# Fitness                       1961
# Laptops                       1310
# TVs                           1255
# dtype: int64

# %%
test_df = pd.read_csv('/content/Test Data.csv')

# %%
test_df
# Out:
#         Unnamed: 0  user_id      aov                   category
# 0                0    43323  19115.0                     Phones
# 1                1    43323  29309.0                     Phones
# 2                2    43323  15293.0                     Phones
# 3                3    43323  23548.0                     Phones
# 4                4    43323    751.0                    Fashion
# ...            ...      ...      ...                        ...
# 172549       86137    12403   1841.0                  Groceries
# 172550       86138    31036    424.0             Back to School
# 172551       86139    12652    617.0                    Fashion
# 172552       86140    35726    634.0  Kitchen cleaning Supplies
# 172553       86141    19871    994.0                    Fashion
#
# [172554 rows x 4 columns]

# %%
test_df.value_counts(test_df.user_id > 5 )
# Out:
# user_id
# True     172540
# False        14
# dtype: int64

# %%
sample_sub = pd.read_csv('/content/Sample Submission.csv')

# %%
sample_sub.head()
# Out:
#    user_id                                pred3
# 0    43323  Laptops, Fashion, Consumer Durables
# 1     4269  Laptops, Fashion, Consumer Durables
# 2    21731  Laptops, Fashion, Consumer Durables
# 3    14422  Laptops, Fashion, Consumer Durables
# 4    12862  Laptops, Fashion, Consumer Durables

# %%
sample_sub.value_counts('pred3')
# Out:
# pred3
# Laptops, Fashion, Consumer Durables    19981
# dtype: int64

# %%
len(sample_sub)
# Out:
# 19981

# %%
sample_sub.pred3[:2][0]
# Out:
# 'Laptops, Fashion, Consumer Durables'

# %%
sample_sub.pred3 = "Phones,Fashion,Home Decor"

# %%
sample_sub.value_counts('pred3')
# Out:
# pred3
# Phones,Fashion,Home Decor    19981
# dtype: int64

# %%
sample_sub.to_csv('./sub.csv',index=False)
