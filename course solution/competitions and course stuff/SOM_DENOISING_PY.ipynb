# %%
# !nvidia-smi
# Out:
# Fri Jul  2 08:34:50 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget https://competitions.codalab.org/my/datasets/download/aba42bbb-958d-4a13-a49e-54c128be9347
# Out:
# --2021-07-02 09:20:11--  https://competitions.codalab.org/my/datasets/download/aba42bbb-958d-4a13-a49e-54c128be9347
# Resolving competitions.codalab.org (competitions.codalab.org)... 129.175.22.230
# Connecting to competitions.codalab.org (competitions.codalab.org)|129.175.22.230|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: https://minioec-proxy.lri.fr/prod-private/dataset_data_file/None/6d56a/SIDD_Small_Raw_Only.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Expires=86400&X-Amz-SignedHeaders=host&X-Amz-Signature=95a917b9515d92f31bfba7253f1efacb9f714eafbacdf0e4be3c13bc65c31f3d&X-Amz-Date=20210702T092012Z&X-Amz-Credential=AZIAIOSAODNN7EX123LE%2F20210702%2Fminioec-proxy%2Fs3%2Faws4_request [following]
# ...

# %%
# !cp /content/aba42bbb-958d-4a13-a49e-54c128be9347 /content/drive/Shareddrives/Tabata/Datasets

# %%
# !unzip /content/drive/Shareddrives/Tabata/Datasets/aba42bbb-958d-4a13-a49e-54c128be9347
# Out:
# Archive:  /content/drive/Shareddrives/Tabata/Datasets/aba42bbb-958d-4a13-a49e-54c128be9347
#    creating: SIDD_Small_Raw_Only/
#    creating: SIDD_Small_Raw_Only/Data/
#    creating: SIDD_Small_Raw_Only/Data/0001_001_S6_00100_00060_3200_L/
#   inflating: SIDD_Small_Raw_Only/Data/0001_001_S6_00100_00060_3200_L/GT_RAW_010.MAT
#   inflating: SIDD_Small_Raw_Only/Data/0001_001_S6_00100_00060_3200_L/METADATA_RAW_010.MAT
#   inflating: SIDD_Small_Raw_Only/Data/0001_001_S6_00100_00060_3200_L/NOISY_RAW_010.MAT
#    creating: SIDD_Small_Raw_Only/Data/0002_001_S6_00100_00020_3200_N/
#   inflating: SIDD_Small_Raw_Only/Data/0002_001_S6_00100_00020_3200_N/GT_RAW_010.MAT
#   inflating: SIDD_Small_Raw_Only/Data/0002_001_S6_00100_00020_3200_N/METADATA_RAW_010.MAT
#   inflating: SIDD_Small_Raw_Only/Data/0002_001_S6_00100_00020_3200_N/NOISY_RAW_010.MAT
#    creating: SIDD_Small_Raw_Only/Data/0003_001_S6_00100_00060_3200_H/
# ...

# %%
pip install gdown

# %%
import gdown

# %%
url1 = '1do7b5zE_Xf8gThqiGutgaILPSFE67rHs'
url = 'https://drive.google.com/uc?id=1do7b5zE_Xf8gThqiGutgaILPSFE67rHs'

# %%
gdown.download('https://drive.google.com/uc?id=1do7b5zE_Xf8gThqiGutgaILPSFE67rHs',output= './output.zip')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-8818d157cb47> in <module>()
# ----> 1 gdown.download('https://drive.google.com/uc?id=1do7b5zE_Xf8gThqiGutgaILPSFE67rHs',output= './output.zip')
#
# TypeError: download() missing 1 required positional argument: 'quiet'

# %%
import zipfile
with zipfile.ZipFile("/content/output.zip","r") as zip_ref:
    zip_ref.extractall("./")

# %%
gdown.pkg_resources.packaging.

# %%
gdown.parse_url('https://drive.google.com/uc?id=1_uVnpefnIfdDK-NScAyNUn7DnixkgkXl?usp=sharing',output = './big_model_file',quiet=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-5becf3413302> in <module>()
# ----> 1 gdown.parse_url('https://drive.google.com/uc?id=1_uVnpefnIfdDK-NScAyNUn7DnixkgkXl?usp=sharing',output = './big_model_file',quiet=False)
#
# TypeError: 'module' object is not callable

# %%
# !tar -xf '/content/20150428_collected_images.tgz'

# %%
import gdown

url = 'https://drive.google.com/uc?id=0B9P1L--7Wd2vNm9zMTJWOGxobkU'
output = '20150428_collected_images.tgz'
gdown.download(url, output, quiet=False)

md5 = 'fa837a88f0c40c513d975104edf3da17'
gdown.cached_download(url, output, md5=md5, postprocess=gdown.extractall)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=0B9P1L--7Wd2vNm9zMTJWOGxobkU
# To: /content/20150428_collected_images.tgz
# 44.7MB [00:00, 73.8MB/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-e22a26249c5b> in <module>()
#       6
#       7 md5 = 'fa837a88f0c40c513d975104edf3da17'
# ----> 8 gdown.cached_download(url, output, md5=md5, postprocess=gdown.extractall)
#
# AttributeError: module 'gdown' has no attribute 'cached_download'
